# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

from lightgbm import LGBMRegressor 
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

from skgbm.xai import AXIL

# %% [markdown]
# # Dataset

# %%
#X, y = make_regression(n_samples=200)
#X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# https://www.kaggle.com/datasets/sudalairajkumar/undata-country-profiles
df = pd.read_csv('archive/kiva_country_profile_variables.csv')

# %%
# https://medium.com/@chaimgluck1/working-with-pandas-fixing-messy-column-names-42a54a6659cd
df.columns = \
    df.columns.str.strip().str.lower() \
        .str.replace('\(.*\)', '') \
        .str.strip() \
        .str.replace(' ', '_') \
        .str.replace(',', '') \
        .str.replace('.', '') \
        .str.replace(':', '')
# Out:
# /tmp/ipykernel_33659/1231718614.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns.str.strip().str.lower() \
# /tmp/ipykernel_33659/1231718614.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns.str.strip().str.lower() \

# %%
df = df.replace({'~0': '0', '\.\.\.': np.nan}, regex=True)
df = df.iloc[:, :14]
df.iloc[:, 2:14] = df.iloc[:, 2:14].convert_dtypes(convert_string=True).astype(float)

# %%
df_medium = df.sample(frac=.5).reset_index()
df_small = df.sample(frac=.1).reset_index()

# %%
# df.convert_dtypes(convert_string=True).dtypes
# df.iloc[:, 2:14].convert_dtypes(convert_string=True).astype(float)

# %%
TARGET = 'gdp_gross_domestic_product'
X, y, labels = df_medium.iloc[:, 2:].drop(columns=TARGET), df_medium[TARGET], df_medium.iloc[:, 0]

# %%
X_train, X_test, y_train, y_test , l_train, l_test = train_test_split(X, y, labels, test_size=.1)

# %% [markdown]
# # Training

# %% [markdown]
# AXIL only explains regressors. Additionaly, for the moment the only accepted loss function is RMSE and its variants (MSE etc.).

# %%
# gbm_reg = LGBMRegressor().fit(X_train, y_train)
# gbm_reg = GradientBoostingRegressor().fit(X_train, y_train)
# gbm_reg = CatBoostRegressor().fit(X_train, y_train)
gbm_reg = XGBRegressor(reg_lambda=0).fit(X_train, y_train)

# %% [markdown]
# # Fitting AXIL

# %%
axil = AXIL(gbm_reg)
axil.fit(X_train, y_train)
# Out:
# AXIL(estimator=XGBRegressor(base_score=None, booster=None, callbacks=None,
#                             colsample_bylevel=None, colsample_bynode=None,
#                             colsample_bytree=None, early_stopping_rounds=None,
#                             enable_categorical=False, eval_metric=None,
#                             feature_types=None, gamma=None, gpu_id=None,
#                             grow_policy=None, importance_type=None,
#                             interaction_constraints=None, learning_rate=None,
#                             max_bin=None, max_cat_threshold=None,
#                             max_cat_to_onehot=None, max_delta_step=None,
#                             max_depth=None, max_leaves=None,
#                             min_child_weight=None, missing=nan,
#                             monotone_constraints=None, n_estimators=100,
#                             n_jobs=None, num_parallel_tree=None, predictor=None,
#                             random_state=None, ...))

# %%
k_test = axil.transform(X_test)
y_pred = gbm_reg.predict(X_test)
np.isclose(y_pred, k_test.T @ y_train, rtol=0.0001).all()
# Out:
# True

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [5, 10]

plt.close()
ax = sns.heatmap(
    k_test, cbar=False,
    xticklabels=l_test, yticklabels=l_train
)
ax.yaxis.tick_right()
ax.set(ylabel=None)
ax.tick_params(axis='both', which='major', labelsize=8)
plt.yticks(rotation=0)
ax.figure.tight_layout()
plt.show()

# %% [markdown]
# ## Clustermap

# %%
k_train = axil.transform(X_train)

import scipy.spatial as sp, scipy.cluster.hierarchy as hc
linkage = hc.linkage(k_train, method='average')
ax = sns.clustermap(k_train, row_linkage=linkage, 
                    col_linkage=linkage, 
                    cmap='Blues',
                    xticklabels=l_train, yticklabels=l_train,
                    cbar_pos=None)
#ax.figure.tight_layout()
ax.ax_heatmap.set_ylabel("")
plt.show()

# %% [markdown]
# ## Network

# %%
import networkx as nx

X, y, labels = \
    df_small.iloc[:, 2:].drop(columns=TARGET), df_small[TARGET], df_small.iloc[:, 0]

# Fitting
gbm = XGBRegressor(reg_lambda=0).fit(X, y)
axil = AXIL(gbm).fit(X)
k_small = axil.transform(X)

graph = k_small.copy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_33659/3763377799.py in <cell line: 7>()
#       5
#       6 # Fitting
# ----> 7 gbm = XGBRegressor(reg_lambda=0).fit(X, y)
#       8 axil = AXIL(gbm).fit(X)
#       9 k_small = axil.transform(X)
#
# ~/.local/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# ~/.local/lib/python3.8/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     986         with config_context(verbosity=self.verbosity):
#     987             evals_result: TrainingCallback.EvalsLog = {}
# --> 988             train_dmatrix, evals = _wrap_evaluation_matrices(
#     989                 missing=self.missing,
#     990                 X=X,
#
# ~/.local/lib/python3.8/site-packages/xgboost/sklearn.py in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#
# ~/.local/lib/python3.8/site-packages/xgboost/sklearn.py in _create_dmatrix(self, ref, **kwargs)
#     906             except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907                 pass
# --> 908         return DMatrix(**kwargs, nthread=self.n_jobs)
#     909
#     910     def _set_evaluation_result(self, evals_result: TrainingCallback.EvalsLog) -> None:
#
# ~/.local/lib/python3.8/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# ~/.local/lib/python3.8/site-packages/xgboost/core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     741             return
#     742
# --> 743         handle, feature_names, feature_types = dispatch_data_backend(
#     744             data,
#     745             missing=self.missing,
#
# ~/.local/lib/python3.8/site-packages/xgboost/data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     968         return _from_tuple(data, missing, threads, feature_names, feature_types)
#     969     if _is_pandas_df(data):
# --> 970         return _from_pandas_df(data, enable_categorical, missing, threads,
#     971                                feature_names, feature_types)
#     972     if _is_pandas_series(data):
#
# ~/.local/lib/python3.8/site-packages/xgboost/data.py in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     415     feature_types: Optional[FeatureTypes],
#     416 ) -> DispatchedDataBackendReturnType:
# --> 417     data, feature_names, feature_types = _transform_pandas_df(
#     418         data, enable_categorical, feature_names, feature_types
#     419     )
#
# ~/.local/lib/python3.8/site-packages/xgboost/data.py in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     389         for dtype in data.dtypes
#     390     ):
# --> 391         _invalid_dataframe_dtype(data)
#     392
#     393     feature_names, feature_types = _pandas_feature_info(
#
# ~/.local/lib/python3.8/site-packages/xgboost/data.py in _invalid_dataframe_dtype(data)
#     281     type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     282     msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 283     raise ValueError(msg)
#     284
#     285
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, The experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:region: object

# %%
np.fill_diagonal(graph, 0)
G = nx.from_numpy_matrix(graph)
nx.draw_circular(
        G, with_labels=True, labels=labels.to_dict(), 
        font_weight='light', node_color = y.to_list(), 
        cmap="Reds", edge_color="gray"
)
